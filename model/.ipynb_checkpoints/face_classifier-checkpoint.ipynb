# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./dataset/dwayne_johnson/390px-Intercontinental_Champion_THE_ROCK.jpg')
img.shape
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv.COLOR_BGR2GRAY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 gray = cv2.cvtColor(img, cv.COLOR_BGR2GRAY)
#
# NameError: name 'cv' is not defined
